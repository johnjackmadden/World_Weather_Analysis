# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from scipy.stats import linregress

# Import the time library and datetime module from the datetime library
import time
from datetime import datetime

#Import requests library and api keys
import requests

import sys
sys.path.append("..")
from config import weather_api_key

# %%
# Create a set of 1500 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
# You can only unzip a zipped tuple once before it is removed from the computer's memory.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# URL for API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the log start
print("Beginning data retrieval")
print("------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through list of cities
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count += 1
        time.sleep(10)
        
    # Create endpoint url for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing record {record_count} of set {set_count} | {city}")
    
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc
                         })
        
    # If an error is experienced, skip the city.
    except Exception as e:
        print(f"Exception of type {e} has occurred: {city} data not returned. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning data retrieval
# ------------------------
# Processing record 1 of set 1 | mar del plata
# Processing record 2 of set 1 | busselton
# Processing record 3 of set 1 | kibaya
# Processing record 4 of set 1 | jucas
# Processing record 5 of set 1 | rikitea
# Processing record 6 of set 1 | tigil
# Processing record 7 of set 1 | timbiqui
# Processing record 8 of set 1 | longyearbyen
# Processing record 9 of set 1 | grand river south east
# Exception of type 'coord' has occurred: grand river south east data not returned. Skipping...
# Processing record 10 of set 1 | waingapu
# Processing record 11 of set 1 | attawapiskat
# Exception of type 'coord' has occurred: attawapiskat data not returned. Skipping...
# Processing record 12 of set 1 | havre-saint-pierre
# Processing record 13 of set 1 | ponta do sol
# Processing record 14 of set 1 | broken hill
# Processing record 15 of set 1 | ushuaia
# Processing record 16 of set 1 | kuliyapitiya
# Processing record 17 of set 1 | mataura
# Processing record 18 of set 1 | bobon
# Processing record 19 of set 1 | hermanus
# Processing record 20 of set 1 | mys shmidta
# Exception of type 'coord' has occurred: mys shmidta data not returned. Skipping...
# Processing record 21 of set 1 | hilo
# Processing record 22 of set 1 | belushya guba
# Exception of type 'coord' has occurred: belushya guba data not returned. Skipping...
# Processing record 23 of set 1 | cape town
# Processing record 24 of set 1 | hobart
# Processing record 25 of set 1 | berdigestyakh
# Processing record 26 of set 1 | saint george
# Processing record 27 of set 1 | jamestown
# Processing record 28 of set 1 | marawi
# Processing record 29 of set 1 | bluff
# Processing record 30 of set 1 | tasiilaq
# Processing record 31 of set 1 | sur
# Processing record 32 of set 1 | faanui
# Processing record 33 of set 1 | barabinsk
# Processing record 34 of set 1 | albany
# Processing record 35 of set 1 | kangaatsiaq
# Processing record 36 of set 1 | guerrero negro
# Processing record 37 of set 1 | bansbaria
# Processing record 38 of set 1 | kapaa
# Processing record 39 of set 1 | mount isa
# Processing record 40 of set 1 | bangkok
# Processing record 41 of set 1 | mae sai
# Processing record 42 of set 1 | kathu
# Processing record 43 of set 1 | punta arenas
# Processing record 44 of set 1 | tuktoyaktuk
# Processing record 45 of set 1 | narrabri
# Processing record 46 of set 1 | ribeira grande
# Processing record 47 of set 1 | kruisfontein
# Processing record 48 of set 1 | huejuquilla el alto
# Processing record 49 of set 1 | nizhneyansk
# Exception of type 'coord' has occurred: nizhneyansk data not returned. Skipping...
# Processing record 50 of set 1 | pangody
# Processing record 52 of set 2 | port lincoln
# Processing record 53 of set 2 | poya
# Processing record 54 of set 2 | tarudant
# Exception of type 'coord' has occurred: tarudant data not returned. Skipping...
# Processing record 55 of set 2 | matara
# Processing record 56 of set 2 | lebu
# Processing record 57 of set 2 | yulara
# Processing record 58 of set 2 | lingao
# Processing record 59 of set 2 | ahipara
# Processing record 60 of set 2 | voi
# Processing record 61 of set 2 | ariquemes
# Processing record 62 of set 2 | muli
# Processing record 63 of set 2 | yellowknife
# Processing record 64 of set 2 | san cristobal
# Processing record 65 of set 2 | esperance
# Processing record 66 of set 2 | upernavik
# Processing record 67 of set 2 | do rud
# Exception of type 'coord' has occurred: do rud data not returned. Skipping...
# Processing record 68 of set 2 | cabadiangan
# Processing record 69 of set 2 | georgetown
# Processing record 70 of set 2 | sitka
# Processing record 71 of set 2 | puerto ayora
# Processing record 72 of set 2 | salalah
# Processing record 73 of set 2 | port alfred
# Processing record 74 of set 2 | cherskiy
# Processing record 75 of set 2 | shanghai
# Processing record 76 of set 2 | katsuura
# Processing record 77 of set 2 | werda
# Processing record 78 of set 2 | mansoa
# Processing record 79 of set 2 | qaanaaq
# Processing record 80 of set 2 | willowmore
# Processing record 81 of set 2 | beatrice
# Processing record 82 of set 2 | inuvik
# Processing record 83 of set 2 | ornskoldsvik
# Processing record 84 of set 2 | chapais
# Processing record 85 of set 2 | palabuhanratu
# Exception of type 'coord' has occurred: palabuhanratu data not returned. Skipping...
# Processing record 86 of set 2 | manta
# Processing record 87 of set 2 | roma
# Processing record 88 of set 2 | castro
# Processing record 89 of set 2 | fairlie
# Processing record 90 of set 2 | arraial do cabo
# Processing record 91 of set 2 | pisco
# Processing record 92 of set 2 | impfondo
# Processing record 93 of set 2 | rocha
# Processing record 94 of set 2 | vaini
# Processing record 95 of set 2 | bubaque
# Processing record 96 of set 2 | gohpur
# Processing record 97 of set 2 | laguna de perlas
# Processing record 98 of set 2 | pevek
# Processing record 99 of set 2 | ascension
# Processing record 100 of set 2 | bethel
# Processing record 101 of set 2 | westpunt
# Exception of type 'coord' has occurred: westpunt data not returned. Skipping...
# Processing record 103 of set 3 | illoqqortoormiut
# Exception of type 'coord' has occurred: illoqqortoormiut data not returned. Skipping...
# Processing record 104 of set 3 | bredasdorp
# Processing record 105 of set 3 | korla
# Processing record 106 of set 3 | chipinge
# Processing record 107 of set 3 | ballina
# Processing record 108 of set 3 | shaartuz
# Exception of type 'coord' has occurred: shaartuz data not returned. Skipping...
# Processing record 109 of set 3 | ortakoy
# Processing record 110 of set 3 | guayaramerin
# Processing record 111 of set 3 | peterhead
# Processing record 112 of set 3 | huarmey
# Processing record 113 of set 3 | comodoro rivadavia
# Processing record 114 of set 3 | cayenne
# Processing record 115 of set 3 | ilulissat
# Processing record 116 of set 3 | vanimo
# Processing record 117 of set 3 | goderich
# Processing record 118 of set 3 | huilong
# Processing record 119 of set 3 | grand gaube
# Processing record 120 of set 3 | muros
# Processing record 121 of set 3 | chuy
# Processing record 122 of set 3 | camopi
# Processing record 123 of set 3 | hithadhoo
# Processing record 124 of set 3 | scarborough
# Processing record 125 of set 3 | lorengau
# Processing record 126 of set 3 | constantine
# Processing record 127 of set 3 | barrow
# Processing record 128 of set 3 | varzea grande
# Processing record 129 of set 3 | kodiak
# Processing record 130 of set 3 | iqaluit
# Processing record 131 of set 3 | grindavik
# Processing record 132 of set 3 | talnakh
# Processing record 133 of set 3 | san quintin
# Processing record 134 of set 3 | eastbourne
# Processing record 135 of set 3 | praia da vitoria
# Processing record 136 of set 3 | batagay
# Processing record 137 of set 3 | codrington
# Processing record 138 of set 3 | kloulklubed
# Processing record 139 of set 3 | sabla
# Processing record 140 of set 3 | miramar
# Processing record 141 of set 3 | takoradi
# Processing record 142 of set 3 | avarua
# Processing record 143 of set 3 | shimoda
# Processing record 144 of set 3 | fuxin
# Processing record 145 of set 3 | viedma
# Processing record 146 of set 3 | gornopravdinsk
# Processing record 147 of set 3 | rundu
# Processing record 148 of set 3 | san carlos de bariloche
# Processing record 149 of set 3 | valleyview
# Processing record 150 of set 3 | burnie
# Processing record 151 of set 3 | leningradskiy
# Processing record 152 of set 3 | meyungs
# Exception of type 'coord' has occurred: meyungs data not returned. Skipping...
# Processing record 154 of set 4 | cidreira
# Processing record 155 of set 4 | los llanos de aridane
# Processing record 156 of set 4 | bargal
# Exception of type 'coord' has occurred: bargal data not returned. Skipping...
# Processing record 157 of set 4 | chokurdakh
# Processing record 158 of set 4 | araouane
# Processing record 159 of set 4 | samusu
# Exception of type 'coord' has occurred: samusu data not returned. Skipping...
# Processing record 160 of set 4 | callaguip
# Processing record 161 of set 4 | lebanon
# Processing record 162 of set 4 | kamenka
# Processing record 163 of set 4 | blackwater
# Processing record 164 of set 4 | urucui
# Processing record 165 of set 4 | darnah
# Processing record 166 of set 4 | inyonga
# Processing record 167 of set 4 | carnarvon
# Processing record 168 of set 4 | caceres
# Processing record 169 of set 4 | constitucion
# Processing record 170 of set 4 | corlu
# Processing record 171 of set 4 | aklavik
# Processing record 172 of set 4 | aitape
# Processing record 173 of set 4 | shelburne
# Processing record 174 of set 4 | olga
# Processing record 175 of set 4 | saldanha
# Processing record 176 of set 4 | lukulu
# Processing record 177 of set 4 | taolanaro
# Exception of type 'coord' has occurred: taolanaro data not returned. Skipping...
# Processing record 178 of set 4 | nieuwpoort
# Processing record 179 of set 4 | atuona
# Processing record 180 of set 4 | lompoc
# Processing record 181 of set 4 | teahupoo
# Processing record 182 of set 4 | payo
# Processing record 183 of set 4 | manbij
# Processing record 184 of set 4 | gap
# Processing record 185 of set 4 | oranjemund
# Processing record 186 of set 4 | beringovskiy
# Processing record 187 of set 4 | zhezkazgan
# Processing record 188 of set 4 | deputatskiy
# Processing record 189 of set 4 | ahar
# Processing record 190 of set 4 | acapulco
# Processing record 191 of set 4 | batagay-alyta
# Processing record 192 of set 4 | konstantinovsk
# Processing record 193 of set 4 | kulhudhuffushi
# Processing record 194 of set 4 | mattru
# Processing record 195 of set 4 | butaritari
# Processing record 196 of set 4 | lima
# Processing record 197 of set 4 | oksfjord
# Processing record 198 of set 4 | sibu
# Processing record 199 of set 4 | nishihara
# Processing record 200 of set 4 | mragowo
# Processing record 201 of set 4 | geraldton
# Processing record 202 of set 4 | trebinje
# Processing record 203 of set 4 | jomalig
# Exception of type 'coord' has occurred: jomalig data not returned. Skipping...
# Processing record 205 of set 5 | dikson
# Processing record 206 of set 5 | durazno
# Processing record 207 of set 5 | leh
# Processing record 208 of set 5 | tumut
# Processing record 209 of set 5 | haines junction
# Processing record 210 of set 5 | cabo san lucas
# Processing record 211 of set 5 | new norfolk
# Processing record 212 of set 5 | tete
# Processing record 213 of set 5 | khani
# Processing record 214 of set 5 | norman wells
# Processing record 215 of set 5 | uhlirske janovice
# Processing record 216 of set 5 | zelenoborskiy
# Processing record 217 of set 5 | lardos
# Processing record 218 of set 5 | sumbe
# Processing record 219 of set 5 | kavieng
# Processing record 220 of set 5 | kleck
# Exception of type 'coord' has occurred: kleck data not returned. Skipping...
# Processing record 221 of set 5 | souillac
# Processing record 222 of set 5 | adrar
# Processing record 223 of set 5 | manavalakurichi
# Processing record 224 of set 5 | sao filipe
# Processing record 225 of set 5 | banda aceh
# Processing record 226 of set 5 | coahuayana
# Processing record 227 of set 5 | peskovka
# Processing record 228 of set 5 | pousat
# Exception of type 'coord' has occurred: pousat data not returned. Skipping...
# Processing record 229 of set 5 | lavumisa
# Processing record 230 of set 5 | joshimath
# Processing record 231 of set 5 | fairbanks
# Processing record 232 of set 5 | badajoz
# Processing record 233 of set 5 | nyuksenitsa
# Processing record 234 of set 5 | port-gentil
# Processing record 235 of set 5 | hofn
# Processing record 236 of set 5 | beihai
# Processing record 237 of set 5 | port said
# Processing record 238 of set 5 | alice springs
# Processing record 239 of set 5 | rio gallegos
# Processing record 240 of set 5 | coquimbo
# Processing record 241 of set 5 | tiksi
# Processing record 242 of set 5 | severo-kurilsk
# Processing record 243 of set 5 | khatanga
# Processing record 244 of set 5 | puerto del rosario
# Processing record 245 of set 5 | shambu
# Processing record 246 of set 5 | saskylakh
# Processing record 247 of set 5 | umuarama
# Processing record 248 of set 5 | barguzin
# Processing record 249 of set 5 | barentsburg
# Exception of type 'coord' has occurred: barentsburg data not returned. Skipping...
# Processing record 250 of set 5 | mantua
# Processing record 251 of set 5 | hobyo
# Processing record 252 of set 5 | vaitupu
# Exception of type 'coord' has occurred: vaitupu data not returned. Skipping...
# Processing record 253 of set 5 | rock sound
# Processing record 254 of set 5 | valparaiso
# Processing record 256 of set 6 | katsina
# Processing record 257 of set 6 | monitos
# Processing record 258 of set 6 | shache
# Processing record 259 of set 6 | marrakesh
# Processing record 260 of set 6 | vila franca do campo
# Processing record 261 of set 6 | sovetskiy
# Processing record 262 of set 6 | bulgan
# Processing record 263 of set 6 | manono
# Processing record 264 of set 6 | ambahta
# Processing record 265 of set 6 | beyneu
# Processing record 266 of set 6 | novyy urengoy
# Processing record 267 of set 6 | victoria
# Processing record 268 of set 6 | mount gambier
# Processing record 269 of set 6 | gravdal
# Processing record 270 of set 6 | henties bay
# Processing record 271 of set 6 | kungurtug
# Processing record 272 of set 6 | kharitonovo
# Processing record 273 of set 6 | itauna
# Processing record 274 of set 6 | black river
# Processing record 275 of set 6 | port elizabeth
# Processing record 276 of set 6 | camacha
# Processing record 277 of set 6 | port hardy
# Processing record 278 of set 6 | strelka
# Processing record 279 of set 6 | shumyachi
# Processing record 280 of set 6 | bambanglipuro
# Processing record 281 of set 6 | ostrovnoy
# Processing record 282 of set 6 | karpathos
# Processing record 283 of set 6 | necochea
# Processing record 284 of set 6 | kaitangata
# Processing record 285 of set 6 | cortona
# Processing record 286 of set 6 | bashmakovo
# Processing record 287 of set 6 | tsihombe
# Exception of type 'coord' has occurred: tsihombe data not returned. Skipping...
# Processing record 288 of set 6 | turukhansk
# Processing record 289 of set 6 | dauphin
# Processing record 290 of set 6 | kavaratti
# Processing record 291 of set 6 | tual
# Processing record 292 of set 6 | egvekinot
# Processing record 293 of set 6 | laguna
# Processing record 294 of set 6 | alofi
# Processing record 295 of set 6 | mahebourg
# Processing record 296 of set 6 | taoudenni
# Processing record 297 of set 6 | padang
# Processing record 298 of set 6 | isangel
# Processing record 299 of set 6 | chagda
# Exception of type 'coord' has occurred: chagda data not returned. Skipping...
# Processing record 300 of set 6 | channel-port aux basques
# Processing record 301 of set 6 | buraydah
# Processing record 302 of set 6 | datong
# Processing record 303 of set 6 | east london
# Processing record 304 of set 6 | usogorsk
# Processing record 305 of set 6 | torit
# Processing record 307 of set 7 | maloshuyka
# Exception of type 'coord' has occurred: maloshuyka data not returned. Skipping...
# Processing record 308 of set 7 | vila velha
# Processing record 309 of set 7 | barra da estiva
# Processing record 310 of set 7 | zhigansk
# Processing record 311 of set 7 | torbay
# Processing record 312 of set 7 | virginia beach
# Processing record 313 of set 7 | tomatlan
# Processing record 314 of set 7 | batemans bay
# Processing record 315 of set 7 | catamarca
# Processing record 316 of set 7 | qeshm
# Processing record 317 of set 7 | dudinka
# Processing record 318 of set 7 | kahului
# Processing record 319 of set 7 | braco do norte
# Processing record 320 of set 7 | gambela
# Processing record 321 of set 7 | karaul
# Exception of type 'coord' has occurred: karaul data not returned. Skipping...
# Processing record 322 of set 7 | sobolevo
# Processing record 323 of set 7 | arrifes
# Processing record 324 of set 7 | ust-ilimsk
# Processing record 325 of set 7 | vestmanna
# Processing record 326 of set 7 | potosi
# Processing record 327 of set 7 | port hedland
# Processing record 328 of set 7 | naze
# Processing record 329 of set 7 | margate
# Processing record 330 of set 7 | bambous virieux
# Processing record 331 of set 7 | nogliki
# Processing record 332 of set 7 | galgani
# Exception of type 'coord' has occurred: galgani data not returned. Skipping...
# Processing record 333 of set 7 | villa juarez
# Processing record 334 of set 7 | nikolskoye
# Processing record 335 of set 7 | san patricio
# Processing record 336 of set 7 | khandyga
# Processing record 337 of set 7 | sentyabrskiy
# Exception of type 'coord' has occurred: sentyabrskiy data not returned. Skipping...
# Processing record 338 of set 7 | ola
# Processing record 339 of set 7 | ongandjera
# Processing record 340 of set 7 | nabire
# Processing record 341 of set 7 | aasiaat
# Processing record 342 of set 7 | jiwani
# Processing record 343 of set 7 | conde
# Processing record 344 of set 7 | kiruna
# Processing record 345 of set 7 | dunedin
# Processing record 346 of set 7 | chivilcoy
# Processing record 347 of set 7 | seymchan
# Processing record 348 of set 7 | la rioja
# Processing record 349 of set 7 | casablanca
# Processing record 350 of set 7 | sao desiderio
# Processing record 351 of set 7 | domoni
# Processing record 352 of set 7 | namibe
# Processing record 353 of set 7 | digby
# Processing record 354 of set 7 | provideniya
# Processing record 355 of set 7 | richards bay
# Processing record 356 of set 7 | lubango
# Processing record 358 of set 8 | kuryk
# Processing record 359 of set 8 | santa fe
# Processing record 360 of set 8 | manzil tamim
# Exception of type 'coord' has occurred: manzil tamim data not returned. Skipping...
# Processing record 361 of set 8 | ixtapa
# Processing record 362 of set 8 | samana
# Processing record 363 of set 8 | kununurra
# Processing record 364 of set 8 | nautla
# Processing record 365 of set 8 | thinadhoo
# Processing record 366 of set 8 | te anau
# Processing record 367 of set 8 | kysyl-syr
# Processing record 368 of set 8 | longlac
# Exception of type 'coord' has occurred: longlac data not returned. Skipping...
# Processing record 369 of set 8 | sibolga
# Processing record 370 of set 8 | lanja
# Processing record 371 of set 8 | bereda
# Processing record 372 of set 8 | nanortalik
# Processing record 373 of set 8 | talavera
# Processing record 374 of set 8 | halifax
# Processing record 375 of set 8 | mareeba
# Processing record 376 of set 8 | belmonte
# Processing record 377 of set 8 | itarema
# Processing record 378 of set 8 | agua branca
# Processing record 379 of set 8 | maldonado
# Processing record 380 of set 8 | juneau
# Processing record 381 of set 8 | mutoko
# Processing record 382 of set 8 | rovaniemi
# Processing record 383 of set 8 | westport
# Processing record 384 of set 8 | itapaci
# Processing record 385 of set 8 | hasaki
# Processing record 386 of set 8 | minot
# Processing record 387 of set 8 | artyk
# Exception of type 'coord' has occurred: artyk data not returned. Skipping...
# Processing record 388 of set 8 | byron bay
# Processing record 389 of set 8 | thompson
# Processing record 390 of set 8 | mirabad
# Processing record 391 of set 8 | tura
# Processing record 392 of set 8 | jacareacanga
# Processing record 393 of set 8 | rawson
# Processing record 394 of set 8 | puerto asis
# Processing record 395 of set 8 | skjervoy
# Processing record 396 of set 8 | kedarnath
# Exception of type 'coord' has occurred: kedarnath data not returned. Skipping...
# Processing record 397 of set 8 | kampot
# Processing record 398 of set 8 | bathsheba
# Processing record 399 of set 8 | airai
# Processing record 400 of set 8 | cockburn town
# Processing record 401 of set 8 | puerto escondido
# Processing record 402 of set 8 | inhambane
# Processing record 403 of set 8 | sorland
# Processing record 404 of set 8 | carutapera
# Processing record 405 of set 8 | teruel
# Processing record 406 of set 8 | davila
# Processing record 407 of set 8 | havoysund
# Processing record 409 of set 9 | sao paulo de olivenca
# Processing record 410 of set 9 | clyde river
# Processing record 411 of set 9 | cedar city
# Processing record 412 of set 9 | biak
# Processing record 413 of set 9 | faya
# Processing record 414 of set 9 | san juan
# Processing record 415 of set 9 | amderma
# Exception of type 'coord' has occurred: amderma data not returned. Skipping...
# Processing record 416 of set 9 | broome
# Processing record 417 of set 9 | saint-augustin
# Processing record 418 of set 9 | berkak
# Processing record 419 of set 9 | saint-philippe
# Processing record 420 of set 9 | bonfim
# Processing record 421 of set 9 | kudahuvadhoo
# Processing record 422 of set 9 | raudeberg
# Processing record 423 of set 9 | atambua
# Processing record 424 of set 9 | general pico
# Processing record 425 of set 9 | grants
# Processing record 426 of set 9 | matagami
# Processing record 427 of set 9 | havelock
# Processing record 428 of set 9 | shitanjing
# Processing record 429 of set 9 | dolinsk
# Processing record 430 of set 9 | klaksvik
# Processing record 431 of set 9 | halalo
# Exception of type 'coord' has occurred: halalo data not returned. Skipping...
# Processing record 432 of set 9 | kyshtovka
# Processing record 433 of set 9 | prachuap khiri khan
# Processing record 434 of set 9 | safwah
# Exception of type 'coord' has occurred: safwah data not returned. Skipping...
# Processing record 435 of set 9 | mandalgovi
# Processing record 436 of set 9 | luderitz
# Processing record 437 of set 9 | arkansas city
# Processing record 438 of set 9 | asau
# Processing record 439 of set 9 | sungairaya
# Processing record 440 of set 9 | ucluelet
# Processing record 441 of set 9 | bukachacha
# Processing record 442 of set 9 | ancud
# Processing record 443 of set 9 | cancun
# Processing record 444 of set 9 | manawar
# Processing record 445 of set 9 | mambolo
# Processing record 446 of set 9 | lagos
# Processing record 447 of set 9 | mpika
# Processing record 448 of set 9 | meerane
# Processing record 449 of set 9 | morros
# Processing record 450 of set 9 | dzhusaly
# Exception of type 'coord' has occurred: dzhusaly data not returned. Skipping...
# Processing record 451 of set 9 | raglan
# Processing record 452 of set 9 | karpogory
# Processing record 453 of set 9 | migori
# Processing record 454 of set 9 | arlit
# Processing record 455 of set 9 | gizo
# Processing record 456 of set 9 | baghmara
# Processing record 457 of set 9 | kaoma
# Processing record 458 of set 9 | huangmei
# Processing record 460 of set 10 | ust-omchug
# Processing record 461 of set 10 | beloha
# Processing record 462 of set 10 | cadiz
# Processing record 463 of set 10 | ponta delgada
# Processing record 464 of set 10 | port shepstone
# Processing record 465 of set 10 | mastic beach
# Processing record 466 of set 10 | salinopolis
# Processing record 467 of set 10 | hirara
# Processing record 468 of set 10 | umm bab
# Processing record 469 of set 10 | mpulungu
# Processing record 470 of set 10 | chamonix-mont-blanc
# Processing record 471 of set 10 | magadi
# Processing record 472 of set 10 | urusha
# Processing record 473 of set 10 | chulumani
# Processing record 474 of set 10 | baykit
# Processing record 475 of set 10 | acatlan
# Processing record 476 of set 10 | srednekolymsk
# Processing record 477 of set 10 | saint-pierre
# Processing record 478 of set 10 | paucartambo
# Exception of type 'coord' has occurred: paucartambo data not returned. Skipping...
# Processing record 479 of set 10 | eyl
# Processing record 480 of set 10 | maceio
# Processing record 481 of set 10 | opuwo
# Processing record 482 of set 10 | axim
# Processing record 483 of set 10 | saleaula
# Exception of type 'coord' has occurred: saleaula data not returned. Skipping...
# Processing record 484 of set 10 | orapa
# Processing record 485 of set 10 | ironton
# Processing record 486 of set 10 | yumen
# Processing record 487 of set 10 | araguaina
# Processing record 488 of set 10 | tecoanapa
# Processing record 489 of set 10 | bengkulu
# Processing record 490 of set 10 | northam
# Processing record 491 of set 10 | lata
# Processing record 492 of set 10 | nador
# Processing record 493 of set 10 | bilibino
# Processing record 494 of set 10 | russell
# Processing record 495 of set 10 | cape elizabeth
# Exception of type 'coord' has occurred: cape elizabeth data not returned. Skipping...
# Processing record 496 of set 10 | baruun-urt
# Processing record 497 of set 10 | gazni
# Exception of type 'coord' has occurred: gazni data not returned. Skipping...
# Processing record 498 of set 10 | quesnel
# Processing record 499 of set 10 | thunder bay
# Processing record 500 of set 10 | vardo
# Processing record 501 of set 10 | pimentel
# Processing record 502 of set 10 | saint-joseph
# Processing record 503 of set 10 | saint-felicien
# Processing record 504 of set 10 | fortuna
# Processing record 505 of set 10 | sinnamary
# Processing record 506 of set 10 | kupang
# Processing record 507 of set 10 | lakshmipur
# Processing record 508 of set 10 | bestobe
# Processing record 509 of set 10 | lethem
# Processing record 511 of set 11 | caravelas
# Processing record 512 of set 11 | hami
# Processing record 513 of set 11 | kailua
# Processing record 514 of set 11 | mirnyy
# Processing record 515 of set 11 | xining
# Processing record 516 of set 11 | rognan
# Processing record 517 of set 11 | toliary
# Exception of type 'coord' has occurred: toliary data not returned. Skipping...
# Processing record 518 of set 11 | pemangkat
# Processing record 519 of set 11 | doaba
# Processing record 520 of set 11 | pauini
# Processing record 521 of set 11 | zyryanka
# Processing record 522 of set 11 | altay
# Processing record 523 of set 11 | touros
# Processing record 524 of set 11 | ketchikan
# Processing record 525 of set 11 | nome
# Processing record 526 of set 11 | kamenskoye
# Exception of type 'coord' has occurred: kamenskoye data not returned. Skipping...
# Processing record 527 of set 11 | aswan
# Processing record 528 of set 11 | dwarka
# Processing record 529 of set 11 | cardoso
# Processing record 530 of set 11 | sept-iles
# Processing record 531 of set 11 | mana
# Processing record 532 of set 11 | pangkalanbuun
# Processing record 533 of set 11 | bonthe
# Processing record 534 of set 11 | okha
# Processing record 535 of set 11 | itanagar
# Processing record 536 of set 11 | jeremie
# Processing record 537 of set 11 | dingle
# Processing record 538 of set 11 | taybad
# Processing record 539 of set 11 | gladstone
# Processing record 540 of set 11 | shimanovsk
# Processing record 541 of set 11 | butajira
# Processing record 542 of set 11 | manokwari
# Processing record 543 of set 11 | coolum beach
# Processing record 544 of set 11 | kuruman
# Processing record 545 of set 11 | aksu
# Processing record 546 of set 11 | elizabeth city
# Processing record 547 of set 11 | coihaique
# Processing record 548 of set 11 | evensk
# Processing record 549 of set 11 | homer
# Processing record 550 of set 11 | prado
# Processing record 551 of set 11 | sedelnikovo
# Exception of type 'coord' has occurred: sedelnikovo data not returned. Skipping...
# Processing record 552 of set 11 | catuday
# Processing record 553 of set 11 | nantucket
# Processing record 554 of set 11 | newport
# Processing record 555 of set 11 | calama
# Processing record 556 of set 11 | kolvereid
# Processing record 557 of set 11 | sechura
# Processing record 558 of set 11 | meulaboh
# Processing record 559 of set 11 | muisne
# Processing record 560 of set 11 | vostok
# Processing record 562 of set 12 | wum
# Processing record 563 of set 12 | normandin
# Processing record 564 of set 12 | turan
# Processing record 565 of set 12 | bull savanna
# Processing record 566 of set 12 | puerto carreno
# Processing record 567 of set 12 | mizan teferi
# Processing record 568 of set 12 | jadu
# Processing record 569 of set 12 | manaure
# Processing record 570 of set 12 | laharpur
# Processing record 571 of set 12 | bainbridge
# Processing record 572 of set 12 | doha
# Processing record 573 of set 12 | liwale
# Processing record 574 of set 12 | port macquarie
# Processing record 575 of set 12 | ondorhaan
# Exception of type 'coord' has occurred: ondorhaan data not returned. Skipping...
# Processing record 576 of set 12 | severo-yeniseyskiy
# Processing record 577 of set 12 | west wendover
# Processing record 578 of set 12 | tanabi
# Processing record 579 of set 12 | okhotsk
# Processing record 580 of set 12 | artesia
# Processing record 581 of set 12 | keuruu
# Processing record 582 of set 12 | andenes
# Processing record 583 of set 12 | am timan
# Processing record 584 of set 12 | ust-tsilma
# Processing record 585 of set 12 | boa vista
# Processing record 586 of set 12 | kiunga
# Processing record 587 of set 12 | atasu
# Processing record 588 of set 12 | neryungri
# Processing record 589 of set 12 | otacilio costa
# Processing record 590 of set 12 | la asuncion
# Processing record 591 of set 12 | bosaso
# Processing record 592 of set 12 | hamilton
# Processing record 593 of set 12 | omboue
# Processing record 594 of set 12 | nagato
# Processing record 595 of set 12 | college
# Processing record 596 of set 12 | tra vinh
# Processing record 597 of set 12 | amga
# Processing record 598 of set 12 | woodward
# Processing record 599 of set 12 | martorell
# Processing record 600 of set 12 | santa cruz de la palma
# Processing record 601 of set 12 | huazolotitlan
# Exception of type 'coord' has occurred: huazolotitlan data not returned. Skipping...
# Processing record 602 of set 12 | kontagora
# Processing record 603 of set 12 | santa maria
# Processing record 604 of set 12 | neustadt
# Processing record 605 of set 12 | waiouru
# Processing record 606 of set 12 | sioux lookout
# Processing record 607 of set 12 | kuusamo
# Processing record 608 of set 12 | talas
# Processing record 609 of set 12 | tottori
# Processing record 610 of set 12 | fuling
# Processing record 611 of set 12 | tahta
# Processing record 613 of set 13 | maridi
# Processing record 614 of set 13 | helena
# Processing record 615 of set 13 | mbandaka
# Processing record 616 of set 13 | burica
# Exception of type 'coord' has occurred: burica data not returned. Skipping...
# Processing record 617 of set 13 | belyy yar
# Processing record 618 of set 13 | alyangula
# Processing record 619 of set 13 | stanari
# Processing record 620 of set 13 | olafsvik
# Processing record 621 of set 13 | cooma
# Processing record 622 of set 13 | ig
# Exception of type 'coord' has occurred: ig data not returned. Skipping...
# Processing record 623 of set 13 | forbes
# Processing record 624 of set 13 | tazovskiy
# Processing record 625 of set 13 | kiboga
# Processing record 626 of set 13 | marzuq
# Processing record 627 of set 13 | borovoy
# Processing record 628 of set 13 | myaundzha
# Processing record 629 of set 13 | taltal
# Processing record 630 of set 13 | khandbari
# Processing record 631 of set 13 | zhicheng
# Processing record 632 of set 13 | north platte
# Processing record 633 of set 13 | tumannyy
# Exception of type 'coord' has occurred: tumannyy data not returned. Skipping...
# Processing record 634 of set 13 | vidim
# Processing record 635 of set 13 | mustasaari
# Processing record 636 of set 13 | rawannawi
# Exception of type 'coord' has occurred: rawannawi data not returned. Skipping...
# Processing record 637 of set 13 | hervey bay
# Processing record 638 of set 13 | lavrentiya
# Processing record 639 of set 13 | amapa
# Processing record 640 of set 13 | orlandia
# Processing record 641 of set 13 | punta alta
# Processing record 642 of set 13 | kirakira
# Processing record 643 of set 13 | samarai
# Processing record 644 of set 13 | soure
# Processing record 645 of set 13 | mopti
# Processing record 646 of set 13 | lenger
# Processing record 647 of set 13 | umzimvubu
# Exception of type 'coord' has occurred: umzimvubu data not returned. Skipping...
# Processing record 648 of set 13 | moose factory
# Processing record 649 of set 13 | sorada
# Processing record 650 of set 13 | muscat
# Processing record 651 of set 13 | maues
# Processing record 652 of set 13 | hambantota
# Processing record 653 of set 13 | spetsai
# Exception of type 'coord' has occurred: spetsai data not returned. Skipping...
# Processing record 654 of set 13 | aracati
# Processing record 655 of set 13 | cocobeach
# Processing record 656 of set 13 | kadhan
# Processing record 657 of set 13 | narsaq
# Processing record 658 of set 13 | harper
# Processing record 659 of set 13 | zavallya
# Processing record 660 of set 13 | benghazi
# Processing record 661 of set 13 | bababe
# Exception of type 'coord' has occurred: bababe data not returned. Skipping...
# Processing record 662 of set 13 | tutoia
# Processing record 664 of set 14 | yar-sale
# Processing record 665 of set 14 | husavik
# Processing record 666 of set 14 | marabba
# Processing record 667 of set 14 | shetpe
# Processing record 668 of set 14 | san gabriel
# Processing record 669 of set 14 | qaqortoq
# Processing record 670 of set 14 | venice
# Processing record 671 of set 14 | petropavlovsk-kamchatskiy
# Processing record 672 of set 14 | yangjiang
# Processing record 673 of set 14 | banjar
# Processing record 674 of set 14 | chernyshevskiy
# Processing record 675 of set 14 | manthani
# Processing record 676 of set 14 | manzhouli
# Processing record 677 of set 14 | mtambile
# Processing record 678 of set 14 | campoverde
# Processing record 679 of set 14 | kambove
# Processing record 680 of set 14 | pangnirtung
# Processing record 681 of set 14 | ayan
# Processing record 682 of set 14 | papetoai
# Processing record 683 of set 14 | west fargo
# Processing record 684 of set 14 | flinders
# Processing record 685 of set 14 | tiarei
# Processing record 686 of set 14 | kankon
# Processing record 687 of set 14 | kibakwe
# Processing record 688 of set 14 | tuy hoa
# Processing record 689 of set 14 | piopio
# Processing record 690 of set 14 | shakawe
# Processing record 691 of set 14 | mitsamiouli
# Processing record 692 of set 14 | kimberley
# Processing record 693 of set 14 | panzhihua
# Processing record 694 of set 14 | rungata
# Exception of type 'coord' has occurred: rungata data not returned. Skipping...
# Processing record 695 of set 14 | benguela
# Processing record 696 of set 14 | lagoa
# Processing record 697 of set 14 | bodaybo
# Processing record 698 of set 14 | yerbogachen
# Processing record 699 of set 14 | bongor
# Processing record 700 of set 14 | beira
# Processing record 701 of set 14 | vega de alatorre
# Processing record 702 of set 14 | lerwick
# Processing record 703 of set 14 | cozumel
# Processing record 704 of set 14 | anito
# Processing record 705 of set 14 | bokspits
# Exception of type 'coord' has occurred: bokspits data not returned. Skipping...
# Processing record 706 of set 14 | fengxian
# Processing record 707 of set 14 | cadillac
# Processing record 708 of set 14 | osoyoos
# Processing record 709 of set 14 | labuhan
# Processing record 710 of set 14 | pakpattan
# Processing record 711 of set 14 | blythe
# Processing record 712 of set 14 | san jose
# Processing record 713 of set 14 | uwayl
# Exception of type 'coord' has occurred: uwayl data not returned. Skipping...
# Processing record 715 of set 15 | sao mateus
# Processing record 716 of set 15 | zilair
# Processing record 717 of set 15 | veydelevka
# Processing record 718 of set 15 | zunyi
# Processing record 719 of set 15 | speightstown
# Processing record 720 of set 15 | kyzyl-suu
# Processing record 721 of set 15 | san policarpo
# Processing record 722 of set 15 | porto santo
# Processing record 723 of set 15 | shchelyayur
# Exception of type 'coord' has occurred: shchelyayur data not returned. Skipping...
# Processing record 724 of set 15 | garmsar
# Processing record 725 of set 15 | port keats
# Processing record 726 of set 15 | pilao arcado
# Exception of type 'coord' has occurred: pilao arcado data not returned. Skipping...
# Processing record 727 of set 15 | maumere
# Processing record 728 of set 15 | cleveland
# Processing record 729 of set 15 | kodinsk
# Processing record 730 of set 15 | bagotville
# Processing record 731 of set 15 | wolmaranstad
# Exception of type 'coord' has occurred: wolmaranstad data not returned. Skipping...
# Processing record 732 of set 15 | belfast
# Processing record 733 of set 15 | sorong
# Processing record 734 of set 15 | umm jarr
# Exception of type 'coord' has occurred: umm jarr data not returned. Skipping...
# Processing record 735 of set 15 | gobabis
# Processing record 736 of set 15 | sistranda
# Processing record 737 of set 15 | pemba
# Processing record 738 of set 15 | erzin
# Processing record 739 of set 15 | lamu
# Processing record 740 of set 15 | mbigou
# Processing record 741 of set 15 | ardistan
# Exception of type 'coord' has occurred: ardistan data not returned. Skipping...
# Processing record 742 of set 15 | falealupo
# Exception of type 'coord' has occurred: falealupo data not returned. Skipping...
# Processing record 743 of set 15 | hualmay
# Processing record 744 of set 15 | berlevag
# Processing record 745 of set 15 | carballo
# Processing record 746 of set 15 | domna
# Processing record 747 of set 15 | oistins
# Processing record 748 of set 15 | vanavara
# Processing record 749 of set 15 | teya
# Processing record 750 of set 15 | zavetnoye
# Processing record 751 of set 15 | staraya poltavka
# Processing record 752 of set 15 | barbar
# Exception of type 'coord' has occurred: barbar data not returned. Skipping...
# Processing record 753 of set 15 | srandakan
# Processing record 754 of set 15 | namatanai
# Processing record 755 of set 15 | moctezuma
# Processing record 756 of set 15 | bara
# Processing record 757 of set 15 | seoul
# Processing record 758 of set 15 | iskateley
# Processing record 759 of set 15 | riyadh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries into a data frame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0       Mar Del Plata      AR -38.0023  -57.5575     52.09        65
# 1           Busselton      AU -33.6500  115.3333     53.65        85
# 2              Kibaya      TZ  -5.3000   36.5667     60.24        93
# 3               Jucas      BR  -6.5253  -39.5275     76.66        74
# 4             Rikitea      PF -23.1203 -134.9692     74.93        76
# 5               Tigil      RU  57.8000  158.6667     44.08        91
# 6            Timbiqui      CO   2.7717  -77.6654     78.49        86
# 7        Longyearbyen      SJ  78.2186   15.6401     42.64        75
# 8            Waingapu      ID  -9.6567  120.2641     77.31        88
# 9  Havre-Saint-Pierre      CA  50.2334  -63.5986     57.56        54
#
#    Cloudiness  Wind Speed Current Description
# 0          40        7.00    scattered clouds
# 1           0        5.21           clear sky
# 2         100        4.90     overcast clouds
# 3          57        5.68       broken clouds
# 4          24        5.82          light rain
# 5         100        6.93     overcast clouds
# 6          96        5.88          light rain
# 7          75        6.91       broken clouds
# 8         100        7.23       moderate rain
# 9           0       20.71           clear sky

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
